# %% [markdown]
# <a href="https://colab.research.google.com/github/youreyesarecameras-dot/fa5programactivity/blob/main/fa5program.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def price_calculator(a,b):
  return a * b


p = int(input("Enter the price of the item you bought: "))
a = int(input("Enter the number of items you bought: "))

print("The total cost of the items you bought is ", price_calculator(p,a))
# Out:
# Enter the price of the item you bought: 20
# Enter the number of items you bought: 2
# The total cost of the items you bought is  40
